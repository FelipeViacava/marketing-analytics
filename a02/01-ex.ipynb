# %%
import pandas as pd

# %%
pd.read_excel(
    "00-data.xlsx",
    sheet_name="base"
)
# Out:
#       id  q1  q2_1  q2_2  q2_3  q2_4  q2_5  q2_6  q2_7  q4  ...  q10_8  q10_9  \
# 0      1   3     2     1     1     1     1     1     1   1  ...      7      6
# 1      2   3     1     2     2     1     2     2     2   2  ...      1      3
# 2      3   1     2     2     1     1     2     2     2   1  ...      5      0
# 3      4   3     1     1     1     1     1     1     1   1  ...      7      7
# 4      5   2     1     1     2     1     2     2     2   1  ...      4      3
# ..   ...  ..   ...   ...   ...   ...   ...   ...   ...  ..  ...    ...    ...
# 367  368   2     2     2     1     1     1     2     1   1  ...      6      5
# 368  369   5     1     1     1     1     1     1     1   2  ...      4      4
# 369  370   3     2     1     1     1     1     2     1   1  ...      7      7
# 370  371   2     1     2     1     1     1     2     2   2  ...      7      7
# 371  372   2     1     1     1     1     2     2     2   3  ...      5      3
#
# ...
